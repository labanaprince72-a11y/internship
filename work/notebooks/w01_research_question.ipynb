# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/labanaprince72-a11y/internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
lane = "Refresh / Content Opportunity Scoring"
print("Provisional lane:", lane)
# Out:
# Provisional lane: Refresh / Content Opportunity Scoring

# %% [markdown]
# lane = "Refresh / Content Opportunity Scoring"
# print("Provisional lane:", lane)

# %% [markdown]
# The decision I want to support is which content pages an SEO or content editor should review first. The output would be a ranked review list containing a priority score and reason codes. The editor could investigate, refresh, improve, or leave each page unchanged. A wrong recommendation could waste editorial time, while missing an important declining page could allow a performance problem to continue. Data or ML may help because several signals need to be considered together rather than relying on one simple rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The dataset contains 30,000 content rows. The median content page has 731 impressions and 7 sessions over 90 days. In addition, 54.2% of rows have a downward trend direction. This suggests that prioritizing pages for review could be useful. However, these numbers do not prove that refreshing a page will improve its performance.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/labanaprince72-a11y/internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Rows and columns:", df.shape)
print("Median 90-day impressions:", df["impressions_90d"].median())
print("Median 90-day sessions:", df["sessions_90d"].median())

print("\nTrend direction:")
print(df["trend_direction"].value_counts(normalize=True).mul(100).round(1))
# Out:
# Rows and columns: (30000, 44)
# Median 90-day impressions: 731.0
# Median 90-day sessions: 7.0
#
# Trend direction:
# trend_direction
# down      54.2
# stable    19.9
# up        14.6
# new        7.5
# flat       3.8
# Name: proportion, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I can describe observed patterns in content visibility, traffic, freshness, CTR, engagement, and trend direction. I may be able to create a directional ranking that supports editorial decision-making. I cannot claim that a particular factor caused a decline, that refreshing a page will definitely increase traffic, or that the analysis predicts Google's rankings. The output should be treated as decision support rather than an automatic final decision.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
